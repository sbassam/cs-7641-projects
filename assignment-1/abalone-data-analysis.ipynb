# %%
import pandas as pd
import data
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data/abalone.data', names = ["Sex", "Length", "Diameter", "Height", 
                                               "Whole weight", "Shucked weight", "Viscera weight",
                                               "Shell weight", "Rings"])

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4175.000000  4175.000000  4175.000000   4175.000000     4175.000000
# mean      0.523965     0.407856     0.139189      0.828468        0.359195
# std       0.120084     0.099230     0.038489      0.490027        0.221713
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.501750
# max       0.815000     0.650000     0.250000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4175.000000   4175.000000  4175.000000
# mean         0.180536      0.238791     9.934132
# std          0.109534      0.139162     3.224802
# min          0.000500      0.001500     1.000000
# ...

# %%
sns.countplot(x= "Rings", data=df)

# %%
# %matplotlib inline
ax = sns.boxplot(data=df[['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight']], palette="Set2")

# %%
g = sns.PairGrid(df)
g.map(plt.scatter);

# %%
df = df[(df["Height"]!=1.13) & (df['Height']!=0.515)]

# %%
data1 = pd.DataFrame(df[['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
       'Viscera weight', 'Shell weight']].values, columns = None)

# %%
data1
# Out:
#       0      1      2      3       4       5       6       7
# 0     M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15
# 1     M   0.35  0.265   0.09  0.2255  0.0995  0.0485    0.07
# 2     F   0.53   0.42  0.135   0.677  0.2565  0.1415    0.21
# 3     M   0.44  0.365  0.125   0.516  0.2155   0.114   0.155
# 4     I   0.33  0.255   0.08   0.205  0.0895  0.0395   0.055
# 5     I  0.425    0.3  0.095  0.3515   0.141  0.0775    0.12
# 6     F   0.53  0.415   0.15  0.7775   0.237  0.1415    0.33
# 7     F  0.545  0.425  0.125   0.768   0.294  0.1495    0.26
# 8     M  0.475   0.37  0.125  0.5095  0.2165  0.1125   0.165
# 9     F   0.55   0.44   0.15  0.8945  0.3145   0.151    0.32
# 10    F  0.525   0.38   0.14  0.6065   0.194  0.1475    0.21
# 11    M   0.43   0.35   0.11   0.406  0.1675   0.081   0.135
# 12    M   0.49   0.38  0.135  0.5415  0.2175   0.095    0.19
# 13    F  0.535  0.405  0.145  0.6845  0.2725   0.171   0.205
# ...

# %%
df["Rings"].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24])

# %%
df["Sex"].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
df.loc[df.Sex=='M', 'Male'] = 1.
df.loc[df.Sex=='F', 'Female'] = 1.
df.loc[df.Sex=='I', 'Infant'] = 1.
df.fillna(0, inplace = True)

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986804  0.899834      0.925372        0.898184
# Diameter        0.986804  1.000000  0.906086      0.925537        0.893385
# Height          0.899834  0.906086  1.000000      0.887712        0.836400
# Whole weight    0.925372  0.925537  0.887712      1.000000        0.969386
# Shucked weight  0.898184  0.893385  0.836400      0.969386        1.000000
# Viscera weight  0.903091  0.899768  0.865710      0.966311        0.931868
# Shell weight    0.897648  0.905271  0.888980      0.955385        0.882681
# Rings           0.556827  0.574792  0.609634      0.540859        0.421442
# Male            0.236103  0.239926  0.235869      0.251378        0.251119
# Female          0.310308  0.319279  0.316922      0.300755        0.265025
# Infant         -0.551546 -0.564395 -0.557870     -0.557815       -0.522078
#
# ...

# %%
a = np.arange(1, 20, 1)
param_range = np.array([(i, i, i) for i in a])

# %%
param_range
# Out:
# array([[ 1,  1,  1],
#        [ 2,  2,  2],
#        [ 3,  3,  3],
#        [ 4,  4,  4],
#        [ 5,  5,  5],
#        [ 6,  6,  6],
#        [ 7,  7,  7],
#        [ 8,  8,  8],
#        [ 9,  9,  9],
#        [10, 10, 10],
#        [11, 11, 11],
#        [12, 12, 12],
#        [13, 13, 13],
#        [14, 14, 14],
#        [15, 15, 15],
#        [16, 16, 16],
#        [17, 17, 17],
#        [18, 18, 18],
#        [19, 19, 19]])

# %%
np.logspace(-6, -1, 5)
# Out:
# array([1.00000000e-06, 1.77827941e-05, 3.16227766e-04, 5.62341325e-03,
#        1.00000000e-01])

# %%
df3 = pd.read_csv('data/abalone.data', names = ["Sex", "Length", "Diameter", "Height", 
                                               "Whole weight", "Shucked weight", "Viscera weight",
                                               "Shell weight", "Rings"])

# %%
df3 = df3[(df3["Height"]!=1.13) & (df3['Height']!=0.515)]

# %%
df3[(df3.Rings<20) & (df3.Rings>10)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 10     F   0.525     0.380   0.140        0.6065          0.1940
# 12     M   0.490     0.380   0.135        0.5415          0.2175
# 15     M   0.500     0.400   0.130        0.6645          0.2580
# 20     M   0.355     0.280   0.095        0.2455          0.0955
# 22     F   0.565     0.440   0.155        0.9395          0.4275
# 25     F   0.560     0.440   0.140        0.9285          0.3825
# 26     F   0.580     0.450   0.185        0.9955          0.3945
# 27     M   0.590     0.445   0.140        0.9310          0.3560
# 28     M   0.605     0.475   0.180        0.9365          0.3940
# 29     M   0.575     0.425   0.140        0.8635          0.3930
# ...

# %%
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4175.000000  4175.000000  4175.000000   4175.000000     4175.000000
# mean      0.523965     0.407856     0.139189      0.828468        0.359195
# std       0.120084     0.099230     0.038489      0.490027        0.221713
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.501750
# max       0.815000     0.650000     0.250000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4175.000000   4175.000000  4175.000000
# mean         0.180536      0.238791     1.355210
# std          0.109534      0.139162     0.496327
# min          0.000500      0.001500     1.000000
# ...
